# %% [markdown]
# # Question 3

# %%
# Import libraries

import numpy as np
import math
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Get the data from Excel

var = pd.read_csv(r'C:\Users\Giovanni Laura\OneDrive\Documents\Giovanni\Warwick\Third Year\MA398 Matrix Analysis & Algorithms\Assignments\Assignment 2\WeatherData.csv')

# Convert to numpy

data = var.to_numpy()

pressure_train = data[:90,0].reshape((90,1))

b_train = data[:90,1].reshape((90,1))

def Vandermonde(x):
    n = np.size(x)
    V = np.zeros((n,3))
    for i in range(3):
        V[:,i] = x**i
    return V

B = Vandermonde(data[:90,0])
print(np.transpose(B))
A = np.matmul(np.matrix.transpose(B),B)

pressure_train = data[:90,0].reshape((90,1))
b_train = data[:90,1].reshape((90,1))

#for k in range(90):
x = np.zeros((3,1))
r = b - np.dot(A,x)
a = (np.linalg.norm(r))**2
print(np.shape(r))
np.dot(A,r)
x += a*r
# Out:
# [[1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#   1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#   1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#   1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#   1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#   1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#   1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#   1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#   1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#   1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#   1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#   1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#   1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#   1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#   1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
# ...
